# %%
import plotly.express as px
import pandas as pd

# %%
data = [
    {'id': 1, 'study_programme': 'Ohjelmointi', 'university': 'Helsingin yliopisto', 'label': 'Ohjelmointi (Helsingin yliopisto)', 'count': 150, 'color': '#1f77b4'},
    {'id': 2, 'study_programme': 'Tietojenkäsittelytiede', 'university': 'Helsingin yliopisto', 'label': 'Tietojenkäsittelytiede (Helsingin yliopisto)', 'count': 120, 'color': '#ff7f0e'},
    {'id': 3, 'study_programme': 'Ohjelmointi', 'university': 'Aalto-yliopisto', 'label': 'Ohjelmointi (Aalto-yliopisto)', 'count': 100, 'color': '#1f77b4'},
    {'id': 4, 'study_programme': 'Tietojenkäsittelytiede', 'university': 'Aalto-yliopisto', 'label': 'Tietojenkäsittelytiede (Aalto-yliopisto)', 'count': 80, 'color': '#ff7f0e'},
]

df = pd.DataFrame(data)

# %%
df
# Out:
#    id         study_programme           university  \
# 0   1             Ohjelmointi  Helsingin yliopisto
# 1   2  Tietojenkäsittelytiede  Helsingin yliopisto
# 2   3             Ohjelmointi      Aalto-yliopisto
# 3   4  Tietojenkäsittelytiede      Aalto-yliopisto
#
#                                           label  count    color
# 0             Ohjelmointi (Helsingin yliopisto)    150  #1f77b4
# 1  Tietojenkäsittelytiede (Helsingin yliopisto)    120  #ff7f0e
# 2                 Ohjelmointi (Aalto-yliopisto)    100  #1f77b4
# 3      Tietojenkäsittelytiede (Aalto-yliopisto)     80  #ff7f0e

# %%
fig = px.treemap(df,
                values='count',
                parents=[""] * len(df),
                ids='id',
                names='study_programme',
                color='color',
    )
fig.show()
